# %% [markdown]
# # Exercise 4: TK
#
# NOTICE: this notebook is a generated stub. TK — replace with the real starter.
#
# Fill in the cells marked `TODO`.

# %%
# TK — imports the exercise expects students to start from.
import polars as pl

# %% [markdown]
# ## Part 1: TK

# %%
# TODO: TK
raise NotImplementedError("TK")

# %% [markdown]
# ## Part 2: TK

# %%
# TODO: TK
raise NotImplementedError("TK")
